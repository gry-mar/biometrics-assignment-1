# %%
import sys
sys.path.insert(0, '..')
from src.utils import image_utils as iu
# %load_ext autoreload
# %autoreload 2
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("../images/img1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
res = iu.change_luminance(image, scale_type=iu.ScaleType.LINEAR, factor=3.5, clip=True)
plt.imshow(res)

# %%
res_quadratic = iu.change_luminance(image, scale_type=iu.ScaleType.QUADRATIC)
plt.imshow(res_quadratic)

# %%
res_const = iu.change_luminance(image, scale_type=iu.ScaleType.CONSTANT, factor=100)
plt.imshow(res_const)

# %%
res_noise = iu.add_gaussian_noise(image, std=0.25, mean=0)
plt.imshow(res_noise)

# %%
iu.calculate_psnr(image, res_noise)
# Out:
# 79.42328690426835

# %%
res_noise = iu.add_gaussian_noise(image, std=0.5, mean=0)
plt.imshow(res_noise)
iu.calculate_psnr(image, res_noise)
# Out:
# 45.317340157709715

# %%
res_noise = iu.add_gaussian_noise(image, std=5, mean=0)
plt.imshow(res_noise)
iu.calculate_psnr(image, res_noise)
# Out:
# 31.30751527044197

# %%
res_noise = iu.add_gaussian_noise(image, std=30, mean=0)
plt.imshow(res_noise)
iu.calculate_psnr(image, res_noise)
# Out:
# 28.1048268316318

# %%
res_noise = iu.add_gaussian_noise(image, std=100, mean=0.2)
plt.imshow(res_noise)
iu.calculate_psnr(image, res_noise)
# Out:
# 27.857919231487756
