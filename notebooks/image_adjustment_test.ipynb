# %%
import sys
sys.path.insert(0, '..')
from src.utils import image_utils as iu

import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("../images/img1.jpg")

plt.imshow(image)

# %%
res = iu.change_luminance(image, scale_type=iu.ScaleType.LINEAR, factor=0.5)
plt.imshow(res)

# %%
res_quadratic = iu.change_luminance(image, scale_type=iu.ScaleType.QUADRATIC)
plt.imshow(res_quadratic)

# %%
res_const = iu.change_luminance(image, scale_type=iu.ScaleType.CONSTANT, factor=30)
plt.imshow(res_const)
